# %% [markdown]
# <a href="https://colab.research.google.com/github/ustab/BTK-PythonTensorflow/blob/master/DEEP_LEARNING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/Churn_Modelling.csv")
X = data.iloc[:,3:13].values
Y = data.iloc[:,13].values

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
#Encoding
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X[:,1] = le.fit_transform(X[:,1])

le2 = preprocessing.LabelEncoder()
X[:,2] = le2.fit_transform(X[:,2])

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

ohe = ColumnTransformer([("ohe",OneHotEncoder(dtype=float),[1])], remainder="passthrough")
X = ohe.fit_transform(X)
X = X[:,1:]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.33,random_state=0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.fit_transform(x_test)

# %%
#Artificial Neural Network
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()
classifier.add(Dense(6, init= "uniform", activation= "relu", input_dim=11)) #11 nöron girişli 6 nöronlu yapı
classifier.add(Dense(6, init= "uniform", activation= "relu")) #Gizli katman
classifier.add(Dense(1, init= "uniform", activation= "sigmoid"))

# %%
classifier.compile(optimizer = 'adam',loss='binary_crossentropy', metrics= ['accuracy'])
classifier.fit(X_train,y_train, epochs=50)
y_pred = classifier.predict(X_test)
# Out:
# Epoch 1/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 2/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 3/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 4/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 5/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 6/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 7/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 8/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 9/50
# 210/210 [==============================] - 0s 1ms/step - loss: 3.5933 - accuracy: 0.2415
# Epoch 10/50
# ...

# %%
y_pred = (y_pred > 0.5)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
print(cm)
